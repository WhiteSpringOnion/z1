# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'jtplot',
#  'quit']

# %%
locals()
# Out:
# {'In': ['',
#   'dir()',
#   'global()',
#   'globals()',
#   'locals()',
#   'locals()',
#   'locals()'],
#  'Out': {1: ['In',
#    'Out',
#    '_',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_i',
#    '_i1',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    'exit',
#    'get_ipython',
#    'jtplot',
#    'quit'],
#   3: {...},
#   4: {...},
#   5: {...}},
#  '_': {...},
#  '_1': ['In',
#   'Out',
#   '_',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_i',
#   '_i1',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   'exit',
#   'get_ipython',
#   'jtplot',
#   'quit'],
#  '_3': {...},
#  '_4': {...},
#  '_5': {...},
#  '__': {...},
#  '___': {...},
#  '__builtin__': <module 'builtins' (built-in)>,
# ...

# %%
from math import *

# %%
locals()
# Out:
# {'In': ['',
#   'dir()',
#   'global()',
#   'globals()',
#   'locals()',
#   'locals()',
#   'locals()',
#   'from math import *',
#   'locals()'],
#  'Out': {1: ['In',
#    'Out',
#    '_',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_i',
#    '_i1',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    'exit',
#    'get_ipython',
#    'jtplot',
#    'quit'],
#   3: {...},
#   4: {...},
#   5: {...},
#   6: {...}},
#  '_': {...},
#  '_1': ['In',
#   'Out',
#   '_',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_i',
#   '_i1',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   'exit',
#   'get_ipython',
#   'jtplot',
#   'quit'],
#  '_3': {...},
#  '_4': {...},
#  '_5': {...},
#  '_6': {...},
#  '__': {...},
#  '___': {...},
# ...

# %%
print(eval('dir()',{}))
# Out:
# ['__builtins__']

# %%
print(eval('dir()',{'sqrt':sqrt, 'pow':pow}))
# Out:
# ['__builtins__', 'pow', 'sqrt']

# %%
print(eval('squareRoot(9)', {'squareRoot': sqrt, 'pow': pow}))
# Out:
# 3.0

# %%
a = 5
print(eval('sqrt(a)', {'a': a, 'sqrt': sqrt}))
# Out:
# 2.23606797749979
