# %% [markdown]
# ## methond 1 to show a pic
# ## ![title](img/test.png)

# %% [markdown]
# ## methond 2 to show a pic
# ## <img src="img/test.png" />

# %% [markdown]
# ---

# %%
from IPython.display import display, Image

obj = Image('./img/test.png', width=300)
obj

# %%
display(obj)    # display (Image())等於是print(string)

# %% [markdown]
# ---

# %% [markdown]
# # 不用print 就能see the value of multiple statements at once
# ## 作法：
#
# `$ vim  ~/.ipython/profile_default/ipython_config.py`
# 貼上以下內容
# > c = get_config()
# > \# Run all nodes interactively
# > c.InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ---

# %% [markdown]
# ## markdown block code Reference
# <https://stackoverflow.com/questions/32156248/how-do-i-set-custom-css-for-my-ipython-ihaskell-jupyter-notebook>
# <https://jupyter.readthedocs.io/en/latest/projects/jupyter-directories.html>
# <http://web.simmons.edu/~grabiner/comm244/weekfour/code-test.html>
# <https://stackoverflow.com/questions/28034783/ipython-notebook-backgound-colour-of-a-cell>

# %% [markdown]
# > # Set  markdown code block color
#
# >`
#  atom /Users/julienjazz/.jupyter/custom/custom.css
#  `
